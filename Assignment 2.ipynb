# %% [markdown]
# # Assignment 2
# * In this assignment you will be working with three data files from iMDB:
#     * cast.csv
#     * release_dates.csv
#     * titles.csv
# * Using the appropriate file(s), answer the following questions
# * Some questions can be completed with one-liners while others are a bit more involved
# * Where appropriate, answers should also provide brief commentary
# * Exclude data that doen't make senss, i.e. data from the future
# * Once complete upload this notebook to your classwork Github repo and post the link on Canvas

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### 1. Conduct a high level assessment of the three data files, i.e. how many records are there, what kind of data, etc. Summarize your findings with annotation.

# %%
cast = pd.read_csv("data/cast.csv")
cast = cast[cast["year"]<2018]
release = pd.read_csv("data/release_dates.csv")
release = release[release["year"]<2018]
titles = pd.read_csv("data/titles.csv")
titles = titles[titles["year"]<2018]

# %%
cast.head(10)
# Out:
#                                                title  year  \
# 0                                     Closet Monster  2015
# 1                                    Suuri illusioni  1985
# 2                                Battle of the Sexes  2017
# 3                               Secret in Their Eyes  2015
# 4                                         Steve Jobs  2015
# 5                             Straight Outta Compton  2015
# 6                             Straight Outta Compton  2015
# 7                                     For Thy Love 2  2009
# 8  Lapis, Ballpen at Diploma, a True to Life Journey  2014
# 9                                       Desire (III)  2014
#
#                         name   type                               character  \
# 0                   Buffy #1  actor                                 Buffy 4
# 1                     Homo $  actor                                  Guests
# 2                    $hutter  actor                         Bobby Riggs Fan
# ...

# %%
len(cast)
# Out:
# 3397718

# %% [markdown]
# The cast dataframe shows a list of 3397718 records which describes the cast of several movies and inlcudes the titles of the movies, the year they were released, the name of the actor or actress, the type, either actor or actreess, the character name and its importance in the film by the "n" value, being 1 the main charracter. The dataframe shows also records into the future, which have been removed foor clarity.

# %%
release.head(10)
# Out:
#                     title  year      country        date
# 0   #73, Shaanthi Nivaasa  2007        India  2007-06-15
# 1                   #BKKY  2016     Cambodia  2017-10-12
# 2                 #Beings  2015      Romania  2015-01-29
# 3               #Captured  2017          USA  2017-09-05
# 4  #Ewankosau saranghaeyo  2015  Philippines  2015-01-21
# 5           #Lucky Number  2015          USA  2015-09-01
# 6      #Nerealnaya lyubov  2014       Russia  2014-02-13
# 7          #Pellichoopulu  2016        India  2016-07-29
# 8            #REALITYHIGH  2017          USA  2017-09-08
# 9                  #Selfi  2017       Russia  2018-02-01

# %%
len(release)
# Out:
# 441045

# %% [markdown]
# The release dataframe shows a list of 441045 records which describes the release dates of several movies and inlcudes the titles of the movies, the year they were released, the country where they were released and the exact release date. The dataframe shows also records into the future, which have been removed foor clarity.

# %%
titles.head(10)
# Out:
#                             title  year
# 0                 Ankara ekspresi  1952
# 1        Ans Vaterland, ans teure  1915
# 2                     Miss Mohini  2002
# 3                   La vera madre  1999
# 4                    O Amerikanos  1993
# 5                  Ostatnia misja  2000
# 6  Physics and the Pinewood Derby  2008
# 7            Duffy of San Quentin  1954
# 8                          Pinsky  2017
# 9            Luang phii theng III  2010

# %%
len(titles)
# Out:
# 217886

# %% [markdown]
# The titles dataframe shows a list of 217886 records which describes the titles of several movies and inlcudes the titles of the movies and the year they were released. The dataframe shows also records into the future, which have been removed foor clarity.

# %% [markdown]
# ### 2. How many movies have the title North by Northwest

# %%
titles[titles["title"] == "North by Northwest"]
# Out:
#                      title  year
# 201761  North by Northwest  1959

# %% [markdown]
# ### 3. How many version of Hamlet are there, when was the first made? the last?

# %%
titles_hamlet = titles[titles['title'].str.contains("Hamlet")]

# %%
len(titles_hamlet)
# Out:
# 54

# %%
titles_hamlet.sort_values(by='year')
# Out:
#                                           title  year
# 79939                                    Hamlet  1910
# 129673                                   Hamlet  1911
# 164637                                   Hamlet  1913
# 150955                       A Sagebrush Hamlet  1919
# 221419                                   Hamlet  1921
# 54760                        Han, hun og Hamlet  1922
# 161129                       Han, hun og Hamlet  1932
# 221201                                   Hamlet  1948
# 220568                                   Hamlet  1954
# 132525                              Hamlet (II)  1964
# 113670                                   Hamlet  1964
# 73929                                    Hamlet  1969
# 204180                                   Hamlet  1973
# 93945       Predstava 'Hamleta' u Mrdusi Donjoj  1974
# 64116                                    Hamlet  1976
# 21870               Intikam Melegi/Kadin Hamlet  1976
# ...

# %%
titles_hamlet.sort_values(by='year').head(1)
# Out:
#         title  year
# 79939  Hamlet  1910

# %%
titles_hamlet.sort_values(by='year').tail(1)
# Out:
#                             title  year
# 207463  Hamlet in the Golden Vale  2017

# %% [markdown]
# There are 54 films with Hamlet in their title, all of these not neccesarily  need to be related to William Shakepeare's original play.
# The first movie was released in 1910, the last movie was released in 2017.

# %% [markdown]
# ### 4. List all the movies called Treasure Island from oldest to newest

# %%
titles[titles["title"] == "Treasure Island"].sort_values(by='year')
# Out:
#                   title  year
# 180911  Treasure Island  1918
# 108853  Treasure Island  1920
# 87953   Treasure Island  1934
# 126321  Treasure Island  1950
# 190233  Treasure Island  1972
# 122150  Treasure Island  1973
# 52099   Treasure Island  1985
# 36752   Treasure Island  1999

# %% [markdown]
# ### 5. How many movies were made in 1950? 1980? 2000? What conclusions can you draw from these data points?

# %%
print(len(titles[titles["year"] == 1950]), "movies were made in 1950")
# Out:
# 1109 movies were made in 1950

# %%
print(len(titles[titles["year"] == 1980]), "movies were made in 1980")
# Out:
# 1750 movies were made in 1980

# %%
print(len(titles[titles["year"] == 2000]), "movies were made in 2000")
# Out:
# 2568 movies were made in 2000

# %% [markdown]
# We can clearly see an increase of movies made through time.

# %% [markdown]
# ### 6. How big was the cast of Metropolis

# %%
print("The cast of Metropolis had", len(cast[cast['title'] == "Metropolis"]), "members")
# Out:
# The cast of Metropolis had 33 members

# %% [markdown]
# ### 7. How many roles for actors were there 1950's? 1990's

# %%
print("There were", len(cast[(cast["year"]>= 1950) & (cast["year"]< 1960)].sort_values(by='year')), "roles for actors in the 1950's")
# Out:
# There were 209890 roles for actors in the 1950's

# %%
print("There were", len(cast[(cast["year"]>= 1990) & (cast["year"]< 2000)].sort_values(by='year')), "roles for actors in 1990's")
# Out:
# There were 361218 roles for actors in 1990's

# %% [markdown]
# ### 8. How many roles for actors & actresses over time? Output should be a line graph

# %%
roles = cast["year"].value_counts().sort_index()

# %%
roles
# Out:
# 1894         3
# 1900         2
# 1905         1
# 1906        17
# 1907         5
#          ...
# 2013    122744
# 2014    129053
# 2015    131337
# 2016    136271
# 2017    136658
# Name: year, Length: 115, dtype: int64

# %%
roles.plot()
# Out:
# <Axes: >

# %% [markdown]
# ### 9. How many "leading roles" were there in the 2000's?

# %%
cast[(cast["year"]>= 2000) & (cast["year"]< 2010) & (cast["n"]== 1)].value_counts()
# Out:
# title                    year  name                 type     character               n
# #73, Shaanthi Nivaasa    2007  Sudeep               actor    Raghu                   1.0    1
# Pride & Loyalty          2002  Charles Durning      actor    Dylan Frier             1.0    1
# Prima dammi un bacio     2003  Stefania Rocca       actress  Adele                   1.0    1
# Prima Primavera          2009  Andor Lukáts         actor    Gábor                   1.0    1
# Prikovannyy              2002  Vladimir Gostyukhin  actor    Pavel Vershin           1.0    1
#                                                                                            ..
# Half a Person            2007  Nigel (VII) Smith    actor    Alex                    1.0    1
# Half Past Ten            2008  Michael F. Stoerzer  actor    Mark                    1.0    1
# Half Past Dead           2002  Steven Seagal        actor    Sasha Petrosevitch      1.0    1
# ...

# %% [markdown]
# There were 23593 leading roles in the 2000's

# %% [markdown]
# ### 10. How many roles received no ranking in the 2000's? 1950's. What conclusions can you draw from these two data points?

# %%
cast[(cast["year"]>= 2000) & (cast["year"]< 2010) & (cast["n"].isnull())]
# Out:
#                     title  year                         name     type  \
# 7          For Thy Love 2  2009                 Bee Moe $lim    actor
# 13       The Replacements  2000            Steven 'Bear'Boyd    actor
# 22       Barrio Gangsters  2009    Marcelino 'Dibujo' Torres    actor
# 34          Heron's Story  2008         David 'Jumbles' Cook    actor
# 57       Justice-For-Hire  2005          Hinton 'Rami' Wells    actor
# ...                   ...   ...                          ...      ...
# 3442866   Vizontele Tuuba  2003                   Tuba Ünsal  actress
# 3442872    Singh Is Kinng  2008                 Preity Üpala  actress
# 3442876  Dondurmam Gaymak  2005                  Tünay Ürper  actress
# 3442883        Issiz Adam  2008                  Sevinç Üçok  actress
# 3442892         Foreldrar  2007  Lilja Guðrún Þorvaldsdóttir  actress
#
#                                        character   n
# 7                                         Thug 1 NaN
# ...

# %%
cast[(cast["year"]>= 1950) & (cast["year"]< 1960) & (cast["n"].isnull())]
# Out:
#                              title  year               name     type  \
# 114                 Die Todesarena  1953   Die 3 Motorellos    actor
# 237           The President's Lady  1953       Linus Aaberg    actor
# 313               Bigger Than Life  1956          Dee Aaker    actor
# 314             Mister Scoutmaster  1953          Dee Aaker    actor
# 316        The Kid from Left Field  1953          Dee Aaker    actor
# ...                            ...   ...                ...      ...
# 3442413       Fridolf sticker opp!  1958  Gunbritt Öhrström  actress
# 3442415  Lille Fridolf blir morfar  1957  Gunbritt Öhrström  actress
# 3442496               I dimma dold  1953      Gudrun Östbye  actress
# 3442498            Vi tre debutera  1953      Gudrun Östbye  actress
# 3442502       Anderssonskans Kalle  1950   Ingrid Östergren  actress
#
#                               character   n
# 114                          Themselves NaN
# 237                        Uncle Alfred NaN
# ...

# %% [markdown]
# We clearly see there are less roles with no ranking in the 1950's decade. This may be caused by two reasons. First, movies cast's in the 1950's were shorter and therfore "extra" roles were not listed. Second, as we previously saw in the 2000's way more movies were produces, and therefore, the absolute number of characters with no ranking would be proportiontaley higher.

# %% [markdown]
# ### 11. Plot the number of films made in each decade

# %%
decades = (titles["year"] / 10).astype(int) * 10

# %%
decades = decades.value_counts()
decades
# Out:
# 2010    57964
# 2000    35730
# 1990    21547
# 1980    19532
# 1970    18476
# 1960    17419
# 1950    12664
# 1930    10245
# 1920     8954
# 1940     8561
# 1910     6752
# 1900       39
# 1890        3
# Name: year, dtype: int64

# %%
decades.plot()
# Out:
# <Axes: >

# %% [markdown]
# ### 12. Plot the number of films with a Rustler character over time

# %%
rustler = cast[cast['character'] == 'Rustler']
rustler
# Out:
#                           title  year               name   type character  \
# 12320              Pinto Canyon  1940     Victor Adamson  actor   Rustler
# 12451         Two Gun Troubador  1939     Victor Adamson  actor   Rustler
# 41718            The Last Stand  1938        Gene Alsace  actor   Rustler
# 71910                    Wanted  1967         Bruno Ariè  actor   Rustler
# 89234             Silent Valley  1935       Jimmy Aubrey  actor   Rustler
# ...                         ...   ...                ...    ...       ...
# 2228961  The Mysterious Avenger  1936  Blackie Whiteford  actor   Rustler
# 2229544            The Marksman  1953      Russ Whiteman  actor   Rustler
# 2248163             The Cowboys  1972        Henry Wills  actor   Rustler
# 2268850        The Frontiersmen  1938  Bob (II) Woodward  actor   Rustler
# 2293242             The Cowboys  1972       Joe Yrigoyen  actor   Rustler
#
#             n
# 12320     NaN
# 12451     NaN
# 41718     NaN
# 71910     NaN
# ...

# %%
rustler = rustler.groupby('year').size().reset_index(name='Rustler')
rustler
# Out:
#     year  Rustler
# 0   1928        1
# 1   1929        5
# 2   1930        1
# 3   1931        1
# 4   1932       23
# 5   1933        1
# 6   1934        6
# 7   1935        7
# 8   1936        8
# 9   1937       15
# 10  1938       20
# 11  1939        2
# 12  1940        4
# 13  1941        1
# 14  1942        5
# 15  1943        2
# 16  1946        5
# 17  1947        1
# 18  1952        1
# 19  1953        5
# 20  1956        2
# 21  1960        1
# 22  1967        1
# 23  1972        9
# 24  1983        1
# 25  1990        1
# 26  1999        3
# 27  2000        2

# %%
rustler.plot(x='year', y='Rustler', kind='bar')
# Out:
# <Axes: xlabel='year'>

# %% [markdown]
# ### 13. What are the top ten character names of all time?

# %%
cast['character'].value_counts().head(10)
# Out:
# Himself        19418
# Dancer         11937
# Extra          10715
# Reporter        7739
# Doctor          6917
# Party Guest     6744
# Student         6486
# Policeman       6409
# Bartender       6228
# Minor Role      6203
# Name: character, dtype: int64

# %% [markdown]
# ### 14. Which actor appeared in the most films in the 1990's decade?

# %%
nineties = cast[(cast["year"]>= 1990) & (cast["year"]< 2000)]

# %%
nineties["name"].value_counts().head(1)
# Out:
# Shakti Kapoor    143
# Name: name, dtype: int64

# %% [markdown]
# ### 15. What are the top 10 roles that start with Science?

# %%
cast[cast['character'].str.startswith("Science")].sort_values(by='n').head(10)
# Out:
#                              title  year                name     type  \
# 2657832                      Angus  1995      Yvette Freeman  actress
# 1888646          Razbudite Mukhina  1968     Nikolay Sergeev    actor
# 326518           A Wreck, a Tangle  2000       Peter Carroll    actor
# 616687                       Mello  2014      Jeffrey Emrich    actor
# 429308          Beyond the Heavens  2013       Brian Copping    actor
# 2604846                      Artie  2000  Leslie Easterbrook  actress
# 706387          Robo-Dog: Airborne  2017    Charles Frierman    actor
# 2180172  The Marc Pease Experience  2009      Ed Wagenseller    actor
# 1945326          From Other Worlds  2004        David Smilow    actor
# 597897       The Manhattan Project  1986       Gregg Edelman    actor
#
#                      character     n
# 2657832        Science Teacher   6.0
# 1888646        Science teacher   6.0
# 326518      Science Voice Over   6.0
# 616687         Science Teacher   6.0
# ...

# %% [markdown]
# ### 16. What film has the largest cast

# %%
largest_cast = cast.groupby(["title","year"])

# %%
largest_cast = cast.groupby('title')['name'].nunique().idxmax()

# %%
largest_cast
# Out:
# 'Around the World in 80 Days'

# %% [markdown]
# ### 17. Generate descriptive statistics for cast size. Briefly comment on the results

# %%
cast.describe()
# Out:
#                year             n
# count  3.397718e+06  2.105937e+06
# mean   1.987192e+03  1.672764e+01
# std    2.834439e+01  3.209081e+01
# min    1.894000e+03  1.000000e+00
# 25%    1.966000e+03  5.000000e+00
# 50%    1.999000e+03  1.000000e+01
# 75%    2.011000e+03  2.100000e+01
# max    2.017000e+03  3.361300e+04

# %% [markdown]
# The descriptive statistics of the cast data frame does not show any valuable information. The data frame is only showing categorical information and therefore the statistics around this data is not very sueful.

# %% [markdown]
# ### 18. How many films has Natalie Portman been in in each year throughout her career?

# %%
natalie = cast[cast['name'] == "Natalie Portman"]
natalie
# Out:
#                                                 title  year             name  \
# 3127057                   A Tale of Love and Darkness  2015  Natalie Portman
# 3127058                             Anywhere But Here  1999  Natalie Portman
# 3127059                               Beautiful Girls  1996  Natalie Portman
# 3127060                                    Black Swan  2010  Natalie Portman
# 3127061                                    Black Swan  2010  Natalie Portman
# 3127062                                      Brothers  2009  Natalie Portman
# 3127063                                        Closer  2004  Natalie Portman
# 3127064                                 Cold Mountain  2003  Natalie Portman
# 3127065                                    Domino One  2005  Natalie Portman
# 3127066                      Everyone Says I Love You  1996  Natalie Portman
# 3127067                                     Free Zone  2005  Natalie Portman
# ...

# %% [markdown]
# ### 19. How many films did Natalie Portman appear in each year where where she was either the top star or co-star?

# %%
natalie_star = natalie[(natalie['n'] == 1) | (natalie['n'] == 2)]
natalie_star
# Out:
#                                                 title  year             name  \
# 3127057                   A Tale of Love and Darkness  2015  Natalie Portman
# 3127058                             Anywhere But Here  1999  Natalie Portman
# 3127060                                    Black Swan  2010  Natalie Portman
# 3127061                                    Black Swan  2010  Natalie Portman
# 3127067                                     Free Zone  2005  Natalie Portman
# 3127069                                 Goya's Ghosts  2006  Natalie Portman
# 3127070                                 Goya's Ghosts  2006  Natalie Portman
# 3127074                                    Jackie (V)  2016  Natalie Portman
# 3127075                                Jane Got a Gun  2015  Natalie Portman
# 3127077            Love and Other Impossible Pursuits  2009  Natalie Portman
# 3127079                Mr. Magorium's Wonder Emporium  2007  Natalie Portman
# ...

# %%
natalie_year = natalie_star.groupby('year').size().reset_index(name='films')
natalie_year
# Out:
#     year  films
# 0   1999      1
# 1   2000      1
# 2   2002      1
# 3   2005      3
# 4   2006      2
# 5   2007      1
# 6   2008      1
# 7   2009      1
# 8   2010      2
# 9   2011      2
# 10  2013      1
# 11  2015      2
# 12  2016      2

# %% [markdown]
# ### 20. Determine how many roles for actor or actress by decade. Plot the output

# %%
roles = pd.DataFrame({'year': (cast['year'] // 10 * 10).astype(int),'type': cast['type']})
roles
# Out:
#          year     type
# 0        2010    actor
# 1        1980    actor
# 2        2010    actor
# 3        2010    actor
# 4        2010    actor
# ...       ...      ...
# 3442897  1980  actress
# 3442898  2000  actress
# 3442899  1980  actress
# 3442900  2000  actress
# 3442901  1990  actress
#
# [3397718 rows x 2 columns]

# %%
roles.groupby(['year', 'type']).size().unstack(fill_value=0).plot()
# Out:
# <Axes: xlabel='year'>

# %%
release['date'] = pd.to_datetime(release['date'])
release
# Out:
#                           title  year      country       date
# 0         #73, Shaanthi Nivaasa  2007        India 2007-06-15
# 1                         #BKKY  2016     Cambodia 2017-10-12
# 2                       #Beings  2015      Romania 2015-01-29
# 3                     #Captured  2017          USA 2017-09-05
# 4        #Ewankosau saranghaeyo  2015  Philippines 2015-01-21
# ...                         ...   ...          ...        ...
# 443481  xXx: State of the Union  2005      Uruguay 2005-04-29
# 443482  xXx: State of the Union  2005       Poland 2005-06-03
# 443483  xXx: State of the Union  2005       Turkey 2005-06-03
# 443484  xXx: State of the Union  2005        China 2005-06-17
# 443485  xXx: State of the Union  2005       Greece 2005-06-24
#
# [441045 rows x 4 columns]

# %% [markdown]
# ### 21. Determine and comment on the day of the week that movies are released. What is notable about release days and months throughout the year? (Use pd.pivot_table)

# %%
release['day_of_week'] = release['date'].dt.day_name()
release
# Out:
#                           title  year      country       date day_of_week
# 0         #73, Shaanthi Nivaasa  2007        India 2007-06-15      Friday
# 1                         #BKKY  2016     Cambodia 2017-10-12    Thursday
# 2                       #Beings  2015      Romania 2015-01-29    Thursday
# 3                     #Captured  2017          USA 2017-09-05     Tuesday
# 4        #Ewankosau saranghaeyo  2015  Philippines 2015-01-21   Wednesday
# ...                         ...   ...          ...        ...         ...
# 443481  xXx: State of the Union  2005      Uruguay 2005-04-29      Friday
# 443482  xXx: State of the Union  2005       Poland 2005-06-03      Friday
# 443483  xXx: State of the Union  2005       Turkey 2005-06-03      Friday
# 443484  xXx: State of the Union  2005        China 2005-06-17      Friday
# 443485  xXx: State of the Union  2005       Greece 2005-06-24      Friday
#
# [441045 rows x 5 columns]

# %%
pivot = pd.pivot_table(release, values='title', index=release['date'].dt.day_name(), aggfunc='count', fill_value=0)
pivot
# Out:
#             title
# date
# Friday     162310
# Monday      37068
# Saturday    31162
# Sunday      15725
# Thursday   125007
# Tuesday     16621
# Wednesday   53152

# %% [markdown]
# The output shows that movies are generally released either on a Friday or on a Thrusday

# %% [markdown]
# ### 22. Can you plot the pivot table? Is the output "correct"? Can you fix it?

# %%
pivot.plot()
# Out:
# <Axes: xlabel='date'>

# %%
day_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
pivot = pivot.reorder_levels(day_order)
pivot = pivot.sort_index()
pivot.plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[51], line 2
#       1 day_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
# ----> 2 pivot = pivot.reorder_levels(day_order)
#       3 pivot = pivot.sort_index()
#       4 pivot.plot()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:7561, in DataFrame.reorder_levels(self, order, axis)
#    7559 axis = self._get_axis_number(axis)
#    7560 if not isinstance(self._get_axis(axis), MultiIndex):  # pragma: no cover
# -> 7561     raise TypeError("Can only reorder levels on a hierarchical axis.")
#    7563 result = self.copy()
#    7565 if axis == 0:
#
# TypeError: Can only reorder levels on a hierarchical axis.

# %% [markdown]
# I am unable to reorder the days of the week in the graph, the error reads "Can only reorder levels on a hierarchical axis."

# %% [markdown]
# ### 23. What films did actors in Star Wars go on to appear in?

# %%
sw_actors = cast[cast['title'].str.contains('Star Wars', case=False)]['name'].unique()
sw_actors
# Out:
# array(['Ian Abercrombie', 'Gerald W. Abrams', 'David Acord',
#        'Charlie Akin', 'Tux Akindoyeni', 'Coinneach Alexander',
#        'Sacha Alexander', 'Giulio Alimenti', 'Adrian Allan',
#        'Hazel (II) Allen', 'Peter Allen', 'Simon (IV) Allen',
#        'John (II) Altman', 'Nicolas Anastassiou', 'Pip Andersen',
#        'Bob (III) Anderson', 'David Ankrum', 'Sebastian Armesto',
#        'Richard Armitage', 'Ray (II) Armstrong', 'Dixie Arnold',
#        'Graham Ashley', 'Alan Austen', 'Mark Anthony Austin',
#        'Apollo Bacala', 'Jason Baird', 'Dee Bradley Baker', 'Glyn Baker',
#        'Kenny Baker', 'Michael Henbury Ballan', 'Paul Bannon',
#        'Adam Bareham', 'D.C. Barns', 'Stephen C. Bastian',
#        'Erik Bauersfeld', 'Scott Beach', 'Ross Beadman', 'Lightning Bear',
#        'Dickey Beer', 'Bobby Bell', 'Alan (II) Bennett', 'Jon Berg',
#        'David Bergelv', 'Mikael Bergsten', 'Urban Bergsten', 'Ahmed Best',
# ...

# %%
sw_selected = cast[cast['name'].isin(sw_actors)]
sw_selected
# Out:
#                                                 title  year              name  \
# 3900                             Addams Family Values  1993   Ian Abercrombie
# 3901                              Blasphemy the Movie  2001   Ian Abercrombie
# 3902                                 Chromiumblue.com  2003   Ian Abercrombie
# 3903                                      Clean Slate  1994   Ian Abercrombie
# 3904                                       Firewalker  1986   Ian Abercrombie
# ...                                               ...   ...               ...
# 3419580                                Enemies Closer  2000     Kristy Wright
# 3419581  Star Wars: Episode III - Revenge of the Sith  2005     Kristy Wright
# 3419582                                Stranded Pearl  2017     Kristy Wright
# 3419583                                      The Crop  2004     Kristy Wright
# 3427205  Star Wars: Episode II - Attack of the Clones  2002  Phoebe Yiamkiati
#
# ...

# %%
sw_films = sw_selected.groupby('name')['title'].unique()
sw_films
# Out:
# name
# Aaliyah Williams         [Star Wars: Episode III - Revenge of the Sith]
# Aaron (IV) Kennedy    [One Square Mile, Run All Night, Star Wars: Ep...
# Adam Bareham          [Star Wars: Episode VI - Return of the Jedi, W...
# Adam Driver           [Bluebird, Frances Ha, Gayby, Hungry Hearts, I...
# Adrian Allan          [Acquainted, Bridget Jones: The Edge of Reason...
#                                             ...
# Zander James               [Star Wars: Episode VII - The Force Awakens]
# Zeljko Stojanovic                       [Star Wars: Threads of Destiny]
# Zeynep Selcuk            [Star Wars: Episode II - Attack of the Clones]
# Zsuzsanna Cseh        [Cloud Atlas, Shark City, Star Wars: Episode I...
# Zuraya Hamilton          [Star Wars: Episode II - Attack of the Clones]
# Name: title, Length: 937, dtype: object

# %%
sw_sorted = sw_selected.sort_values(by='title') 
sw_sorted = sw_sorted['title'].tolist()
sw_sorted = list(set(sw_sorted))
sw_sorted
# Out:
# ['Much Ado About Nothing',
#  'The Affair of the Necklace',
#  'The Life Before Her Eyes',
#  'Wish Me Luck',
#  "Melanie's Grave",
#  'London Road',
#  'The Cowboy Way',
#  'Last Days in the Desert',
#  'Cast a Dark Shadow',
#  'Looking for Alibrandi',
#  'Caravans',
#  'Confessions of a Pop Performer',
#  'The Mission',
#  'Waterboys',
#  'The Railway Man',
#  'A Dangerous Age',
#  'Hide and Seek',
#  'Suttons Case',
#  'Frozen Kiss',
#  'Rage',
#  'Herostratus',
#  'Heavens Above!',
#  'The Veteran',
#  'Who?',
#  'A Million Ways to Die in the West',
#  'The Ace of Spades',
#  'South Central',
#  'Meningen med Hugo',
#  'The Bulldog Breed',
#  'Dangerous Beauty',
#  'The Current War',
#  'The Black Shield of Falworth',
#  'Big Fish',
#  'Crime and Punishment',
#  'Flawless',
#  'The Garbage Pail Kids Movie',
#  'Giant Steps',
#  'Laid in America',
#  'Open Window',
#  'Not Wanted on Voyage',
#  'Rise of the Footsoldier Part II',
#  'Out of Bounds',
#  'Sushi Girl',
# ...
